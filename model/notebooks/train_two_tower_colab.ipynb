# %% [markdown]
# # Two-Tower Model Training (Colab GPU)
# Upload `data/processed/train.csv`, `data/processed/val.csv`, and the four files from `model/two_tower/` (architecture.py, dataset.py, losses.py, train.py) before running.
# Use Runtime > Change runtime type > GPU before executing.

# %%
# !pip install torch pandas numpy -q

# %%
from google.colab import files
import os
os.makedirs('data/processed', exist_ok=True)
os.makedirs('model/two_tower', exist_ok=True)
os.makedirs('model/artifacts', exist_ok=True)
print('Upload train.csv and val.csv into data/processed, and architecture.py, dataset.py, losses.py, train.py into model/two_tower using the Colab file browser on the left.')

# %%
import sys
sys.path.append('.')
from model.two_tower.train import main
main()

# %%
from google.colab import files
files.download('model/artifacts/two_tower_best.pt')
files.download('model/artifacts/vocab.json')
files.download('model/artifacts/training_history.json')
print('Download these three files and place them into your local model/artifacts/ folder, then run export.py locally.')
